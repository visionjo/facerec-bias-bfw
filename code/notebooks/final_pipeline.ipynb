# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pathlib
import sys
sys.path.append("../")

# %%
from facebias.analysis import create_bias_analysis_plots

# %%
image_pair_path = "../../data/bfw-pairs.csv"
image_list_path = "../../data/bfw-list.csv"
embedding_dir_path = "../../data/features/senet50"
processed_data = "../../data/new-bfw-datatable.pkl"

# %%
create_bias_analysis_plots(image_pair_path, image_list_path, embedding_dir_path, save_processed_data=new_processed_data)
